# %%
import matplotlib.pyplot as plt
# %matplotlib inline
try:
    del str
except:
    pass
import pandas as pd
import numpy as np

# %% [markdown]
# ### Basic Graph

# %%
import matplotlib.pyplot as plt
import importlib
importlib.reload(plt)
x = [1,2,3]
y = [4,5,6]
plt.plot(x,y)
plt.title('Our First Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import importlib
importlib.reload(plt)
print("Matplotlib imported successfully")
# 2: Creating a Simple Line Plot
x = [1,2,3,4,5]
y = [10,20,30,40,50]
plt.plot(x,y)
# plt.show()

#  3: Adding X and Y Axis Labels
plt.xlabel("X Axis",color = "blue",fontsize = 12)
plt.ylabel('Y Axis',color = 'blue',fontsize = 12)
# plt.show()

# 4.Add a Title:
plt.title("Hey My First Graph !")
# plt.grid(True)
plt.grid(color='yellow', linestyle='--', linewidth=1)
plt.show()
# Out:
# Matplotlib imported successfully

# %%
# Practice Task:Plot the following:
# X = [1, 2, 3, 4, 5]
# Y = [5, 10, 15, 12, 18]
# X-label: "Week"
# Y-label: "Orders"
# Title: "Weekly Orders Trend"
# Enable grid
import matplotlib.pyplot as plt
import importlib
importlib.reload(plt)

x = [1, 2, 3, 4, 5]
Y = [5, 10, 15, 12, 18]
# plt.plot(x,y,'r-.')
plt.plot(x, y, color='red', linestyle='--', marker='o')
plt.xlabel('X Axis',color = 'Blue')
plt.ylabel('Y Axis',color ='Blue')
plt.title('Weekly Orders Trend',color = 'Blue')
plt.grid(True)
plt.savefig('Weekly_orders1.png',dpi=300, bbox_inches='tight')
plt.show()

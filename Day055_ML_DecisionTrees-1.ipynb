# %% [markdown]
# ### Decision Trees
# What is a Decision Tree?
#
# A Decision Tree is like a flowchart.
#
# At each step, it asks a yes/no question about the data → splits into groups → until it can make a decision.
#
# 👉 Example: Predict if someone will play cricket today.
#
# Is it raining?
#
# Yes → Don’t play
#
# No → Next question: Is it too hot?
#
# Yes → Don’t play
#
# No → Play ✅
#
# ### Splitting
#
# At each node (question), the tree splits the data into groups.
#
# The goal: make groups as pure as possible (each group should mostly belong to one class).
#
#
# ### Gini Impurity (measure of “impurity”)
#
# Think of it as: “How mixed is this group?”
#
# If a group has all same class → Gini = 0 (pure).
#
# If a group is half-half (like 50% yes, 50% no) → Gini is higher (impure).
#
# Formula (don’t worry too much):
#
# ### Entropy (another measure of impurity)
#
# Another way to measure impurity.
#
# Entropy is 0 when group is pure, and higher when mixed.
#
# Formula uses log (don’t memorize now):

# %% [markdown]
# ### ✅ In short:
#
# Splitting → how the tree decides to divide data.
#
# Gini & Entropy → math ways to measure “how good” a split is (pure vs mixed).

# %%
# Step 1: Import libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Step 2: Create the dataset
data = {
    "Age": [12, 35, 40, 10],
    "Weather": ["Hot", "Hot", "Cold", "Cold"],
    "Buy": ["Yes", "Yes", "No", "No"]
}

df = pd.DataFrame(data)

# Step 3: Convert categorical column "Weather" into numbers
df["Weather"] = df["Weather"].map({"Hot": 1, "Cold": 0})
df["Buy"] = df["Buy"].map({"Yes": 1, "No": 0})

X = df[["Age", "Weather"]]   # Features
y = df["Buy"]                # Target

# Step 4: Create and train the decision tree
model = DecisionTreeClassifier(criterion="gini", random_state=42)
model.fit(X, y)

# Step 5: Visualize the decision tree
plt.figure(figsize=(6,4))
plot_tree(model, feature_names=["Age", "Weather"], class_names=["No", "Yes"], filled=True)
plt.show()

# Step 6: Make predictions
print("Prediction for Age=15, Weather=Hot:", model.predict([[15, 1]])[0])  # Expect Yes
print("Prediction for Age=30, Weather=Cold:", model.predict([[30, 0]])[0]) # Expect No
# Out:
# Prediction for Age=15, Weather=Hot: 1
# Prediction for Age=30, Weather=Cold: 0
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

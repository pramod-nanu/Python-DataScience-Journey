# %% [markdown]
# ### EDA Part 1 – Batsmen Analysis

# %% [markdown]
# ### Topic 1 : Top run scorers

# %%
# Step 1: Load the aggregated dataset
import pandas as pd
df = pd.read_csv("Data/IPL_Playerwise_Data.csv")
print(df.head())
print("#############")
print("#############")

# Step 2: Sort players by total runs
top_scorers = df.sort_values(by="TotalRuns", ascending=False).head(10)
print(top_scorers[["Player", "TotalRuns"]])
print("#############")
print("#############")

# Visualize
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.barplot(y='Player',x='TotalRuns',data =top_scorers,palette="Blues_r")
plt.title("Top Run Scorer")
plt.xlabel('Total Runs')
plt.ylabel('Players Name')
plt.show()
# Out:
#            Player  Matches  TotalRuns  TotalBalls  Fours  Sixes  StrikeRate  \
# 0  AB de Villiers        2        126          89     19      7       141.6
# 1   Andre Russell        5        214         197     23     19       108.6
# 2     Chris Gayle        3        130         104     14     14       125.0
# 3    David Warner        8        289         278     31     30       104.0
# 4        KL Rahul        7        200         236     22     13        84.7
#
#    BoundaryPct
# 0         93.7
# 1         96.3
# 2        107.7
# 3        105.2
# 4         83.0
# #############
# #############
#            Player  TotalRuns
# 7  Shikhar Dhawan        484
# 5        MS Dhoni        307
# 3    David Warner        289
# 1   Andre Russell        214
# 4        KL Rahul        200
# 9     Virat Kohli        167
# 8    Suresh Raina        143
# 2     Chris Gayle        130
# 6    Rohit Sharma        128
# 0  AB de Villiers        126
# #############
# #############
# ...

# %% [markdown]
# ### Topic 2: Top Strike Rates (with min 100 balls faced)

# %%
print(df.head())

# Step 2: Filter players (≥ 100 balls)
qualified = df[df['TotalBalls'] >= 100]
print("#############")
print("#############")

# Step 3: Sort by Strike Rate
top_strike = qualified.sort_values(by='StrikeRate',ascending = False).head(10)
print(top_strike[['Player','StrikeRate','TotalRuns','TotalBalls']])
print("#############")
print("#############")

# Step 4: Visualize (Bar Chart)
sns.barplot(x='StrikeRate',y='Player',data=top_strike,palette="Greens_r")
plt.title("Best StrikeRate")
plt.xlabel('Player')
plt.ylabel('StrikeRate')
plt.plot()
# Out:
#            Player  Matches  TotalRuns  TotalBalls  Fours  Sixes  StrikeRate  \
# 0  AB de Villiers        2        126          89     19      7       141.6
# 1   Andre Russell        5        214         197     23     19       108.6
# 2     Chris Gayle        3        130         104     14     14       125.0
# 3    David Warner        8        289         278     31     30       104.0
# 4        KL Rahul        7        200         236     22     13        84.7
#
#    BoundaryPct
# 0         93.7
# 1         96.3
# 2        107.7
# 3        105.2
# 4         83.0
# #############
# #############
#            Player  StrikeRate  TotalRuns  TotalBalls
# 7  Shikhar Dhawan       214.2        484         226
# 5        MS Dhoni       204.7        307         150
# 2     Chris Gayle       125.0        130         104
# 9     Virat Kohli       123.7        167         135
# 1   Andre Russell       108.6        214         197
# 3    David Warner       104.0        289         278
# ...

# %% [markdown]
# ### Topic 3: Boundary %

# %%
df.head(5)
df['BoundryPCT'] = ((df['Fours'] * 4 + df['Sixes'] * 6) / df['TotalRuns']) * 100
df['BoundryPCT']= df['BoundryPCT'].round(1)

# Step 3: Sort by boundary %
top_boundry = df.sort_values(by = 'BoundryPCT',ascending= False).head(5)
print(top_boundry[['Player','TotalRuns','BoundryPCT']])

# Step 4: Visualize
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.barplot(x = 'BoundryPCT',y = 'Player',data = top_boundry,palette='Oranges_r')
plt.xlabel("Boundary % of Runs")
plt.ylabel("Player")
plt.show()
# Out:
#            Player  TotalRuns  BoundryPCT
# 7  Shikhar Dhawan        484       110.7
# 2     Chris Gayle        130       107.7
# 3    David Warner        289       105.2
# 1   Andre Russell        214        96.3
# 0  AB de Villiers        126        93.7
# /var/folders/rx/bfj9nybj02jf94xlvrjnp9nr0000gn/T/ipykernel_4308/103382142.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'BoundryPCT',y = 'Player',data = top_boundry,palette='Oranges_r')

# %% [markdown]
# ### Topic 4: Bar chart for Top 10 Run Scorers

# %%
# Step 1: Get Top 10 Run Scorers
top_scorers = df.sort_values(by ='TotalRuns',ascending = False).head(10)
#print(top_scorers[['Player','TotalRuns']])
plt.figure(figsize=(10,5))
sns.barplot(x="TotalRuns", y="Player", data=top_scorers, palette="Blues_r")
plt.title("Top 10 Run Scorers")
plt.xlabel("Total Runs")
plt.ylabel("Player")
plt.show()
# Out:
# /var/folders/rx/bfj9nybj02jf94xlvrjnp9nr0000gn/T/ipykernel_4308/83469714.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="TotalRuns", y="Player", data=top_scorers, palette="Blues_r")

# %% [markdown]
# ### Topic 5: Scatterplot – Runs vs Strike Rate

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.scatterplot(x="TotalRuns", y="StrikeRate", data=df, hue="Player", s=100)
plt.title("Runs vs Strike Rate")
plt.xlabel("Total Runs")
plt.ylabel("Strike Rate")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")  # Move legend outside
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="TotalRuns", y="StrikeRate", data=df, s=100, color="blue")

for i, row in df.iterrows():
    
    # plt.text(row["TotalRuns"]+5, row["StrikeRate"], row["Player"], fontsize=9)
    plt.text(row["TotalRuns"]+5, row["StrikeRate"], 
             f"{row['Player']} ({row['StrikeRate']})", fontsize=9)

plt.title("Runs vs Strike Rate (with Player Labels)")
plt.xlabel("Total Runs")
plt.ylabel("Strike Rate")
plt.show()
